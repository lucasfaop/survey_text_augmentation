# %% [markdown]
# # Imports and Setups

# %%
! pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 5.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 36.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.6.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.9 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 55.9 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.6.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.2

# %%
! pip install nlpaug==1.1.7
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nlpaug==1.1.7
#   Downloading nlpaug-1.1.7-py3-none-any.whl (405 kB)
#      |████████████████████████████████| 405 kB 5.1 MB/s
# Installing collected packages: nlpaug
# Successfully installed nlpaug-1.1.7

# %%
! pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.1 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 3.7 MB/s
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.19.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.12.0+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.1.96)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2019.12.20)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (4.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (1.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=8518517601dd7b1ca3177661bd33477fe15ce322ced73b979e56db8d81af920d
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.2.0

# %% [markdown]
# Lendo o Arquivo

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()

# %%
num_gen = 5
perc = 100

# %% [markdown]
# Gerando Base Percentual

# %%
arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_ironic_'+str(perc)+'_original.csv'
base_cru_1p = pd.read_csv(arq, encoding='utf-8', sep=';', decimal = ',')

# %%
base_cru_1p.head()
# Out:
#                                                texto  label
# 0  Sweet United Nations video. Just in time for C...      1
# 1  @mrdahl87 We are rumored to have talked to Erv...      1
# 2  Hey there! Nice to see you Minnesota/ND Winter...      1
# 3                3 episodes left I'm dying over here      0
# 4  I can't breathe! was chosen as the most notabl...      1

# %%
base_cru_1p.shape
# Out:
# (1909, 2)

# %% [markdown]
# Só rodar quando gerar o original

# %%
repeticoes = 1

# %%
# arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_ironic_'+str(perc)+'_original.csv'
# base_cru_1p.to_csv(arq, encoding='utf-8', index=False, sep=';', decimal = ',')

# %%
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as naf

from nlpaug.util import Action

# %% [markdown]
# # Embedding Word2Vec

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet', 'por')
nltk.download('wordnet')
nltk.download('omw')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to por...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw.zip.
# True

# %%
import nlpaug.flow as naf
aug_ppdb = naw.SynonymAug(aug_src='ppdb', model_path='/content/drive/My Drive/Colab Notebooks/parafraseadores/ppdb-2.0-m-all')

# %%
exp_ppdb = []

for i in range(repeticoes):
  base_cru_1p_emb = base_cru_1p.copy()
  base_cru_1p_emb['parafraseador'] = base_cru_1p_emb['texto'].progress_apply(lambda x:aug_ppdb.augment(x,num_gen))
  base_cru_1p_emb = base_cru_1p_emb.explode('parafraseador').reset_index(drop=True)
  exp_ppdb.append(base_cru_1p_emb)

  arquivo = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_ironic_'+str(perc)+'_ppdb'+str(i+1)+'.csv'
  exp_ppdb[i].to_csv(arquivo, encoding='utf-8', index=False, sep=';', decimal = ',')
# Out:
# 100%|██████████| 3817/3817 [00:28<00:00, 132.82it/s]

# %%
exp_ppdb[i].head(30)
# Out:
#                                                 texto  label  \
# 0   Sweet United Nations video. Just in time for C...      1
# 1   Sweet United Nations video. Just in time for C...      1
# 2   Sweet United Nations video. Just in time for C...      1
# 3   Sweet United Nations video. Just in time for C...      1
# 4   Sweet United Nations video. Just in time for C...      1
# 5   @mrdahl87 We are rumored to have talked to Erv...      1
# 6   @mrdahl87 We are rumored to have talked to Erv...      1
# 7   @mrdahl87 We are rumored to have talked to Erv...      1
# 8   @mrdahl87 We are rumored to have talked to Erv...      1
# 9   @mrdahl87 We are rumored to have talked to Erv...      1
# 10  Hey there! Nice to see you Minnesota/ND Winter...      1
# 11  Hey there! Nice to see you Minnesota/ND Winter...      1
# 12  Hey there! Nice to see you Minnesota/ND Winter...      1
# 13  Hey there! Nice to see you Minnesota/ND Winter...      1
# 14  Hey there! Nice to see you Minnesota/ND Winter...      1
# 15                3 episodes left I'm dying over here      0
# 16                3 episodes left I'm dying over here      0
# 17                3 episodes left I'm dying over here      0
# 18                3 episodes left I'm dying over here      0
# 19                3 episodes left I'm dying over here      0
# 20  I can't breathe! was chosen as the most notabl...      1
# 21  I can't breathe! was chosen as the most notabl...      1
# 22  I can't breathe! was chosen as the most notabl...      1
# 23  I can't breathe! was chosen as the most notabl...      1
# 24  I can't breathe! was chosen as the most notabl...      1
# 25  You're never too old for Footie Pajamas. http:...      0
# 26  You're never too old for Footie Pajamas. http:...      0
# 27  You're never too old for Footie Pajamas. http:...      0
# 28  You're never too old for Footie Pajamas. http:...      0
# 29  You're never too old for Footie Pajamas. http:...      0
#
#                                         parafraseador
# 0   Sweet United Nations videotape. Just in timefr...
# 1   Sweet United Nations videotape. Just in timefr...
# 2   Sweet United Nations videotape. Just in timefr...
# 3   Sweet United Nations videotape. Just in timefr...
# 4   Sweet United Nations videotape. Just in timefr...
# 5   @ mrdahl87 We understand circulated to accommo...
# 6   @ mrdahl87 We benefit circulated to participat...
# 7   @ mrdahl87 We manage circulated to perceived d...
# 8   @ mrdahl87 We rise circulated to incorporated ...
# 9   @ mrdahl87 We negotiate circulated to accommod...
# 10  Hey there! Nice to accesses you Minnesota / ND...
# 11  Hey there! Nice to witnessed you Minnesota / N...
# 12  Hey there! Nice to illustrated you Minnesota /...
# 13  Hey there! Nice to were you Minnesota / ND Win...
# 14  Hey there! Nice to discovered you Minnesota / ...
# 15         3 circumstances left I ' m lying over here
# 16      3 episodes left I ' millions dying over there
# 17      3 episodes acceded I ' meters dying over here
# 18          3 episodes forsworn I ' m death over here
# 19                3 series left I ' m death over here
# 20  I can ' t breathing! gotta adjudicated as the ...
# 21  I can ' t breathing! received postponed as the...
# 22  I can ' t breathe! right supposed as the mostl...
# 23  I can ' t breathe! maybe ascertained as the mo...
# 24  I can ' t breathe! identified excluded as the ...
# 25  You ' concerning ever too old for Footie Pajam...
# 26  You ' regarding ever too old for Footie Pajama...
# 27  You ' concerning ever too old for Footie Pajam...
# 28  You ' addressing ever too old for Footie Pajam...
# 29  You ' respecting ever too old for Footie Pajam...

# %%
(exp_ppdb[i]['texto'] == exp_ppdb[i]['parafraseador']).astype('int').mean()
# Out:
# 0.015981137018600995
