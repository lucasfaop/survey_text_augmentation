# %% [markdown]
# Instalando Pacote

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-6dba36e4-4f86-68b3-1c00-5948d51f34f2)

# %%
# !nvidia-smi
# Out:
# Thu Jun  2 00:11:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacrebleu
#   Downloading sacrebleu-2.1.0-py3-none-any.whl (92 kB)
#      |████████████████████████████████| 92 kB 3.4 MB/s
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.21.6)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.4.0 sacrebleu-2.1.0

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 5.5 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 38.5 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.12.0+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 40.4 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.6 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2019.12.20)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 20.3 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 39.2 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.7.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (4.11.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=5d5329a9fa31bbaa83276b1deadcc6c87f50902839e2d7dc01a74cff11c5e329
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.7.0 pyyaml-6.0 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.19.2

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
perc= 20

# %%
import pandas as pd

i=0

arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_keyarg'+str(i+1)+'.csv'
keyboard = pd.read_csv(arq, sep = ';', decimal = ',')

arq =  '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_eda'+str(i+1)+'.csv'
eda = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_emb'+str(i+1)+'.csv'
embed = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_bert'+str(i+1)+'.csv'
bert = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_back_trans'+str(i+1)+'.csv'
back_trans = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_deep_back_trans'+str(i+1)+'.csv'
deep_back = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_parrot'+str(i+1)+'.csv'
parrot = pd.read_csv(arq, sep = ';', decimal = ',')


arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_protaug'+str(i+1)+'.csv'
protaug = pd.read_csv(arq, sep = ';', decimal = ',')


arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_lambada'+str(i+1)+'.csv'
lambada = pd.read_csv(arq, sep = ';', decimal = ',')
arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_ppdb'+str(i+1)+'.csv'
ppdb = pd.read_csv(arq, sep = ';', decimal = ',')

arq = '/content/drive/My Drive/Colab Notebooks/paper_asoc/perc_' +str(perc) + '/base_trec_'+str(perc)+'_ssmba'+str(i+1)+'.csv'
ssmba = pd.read_csv(arq, sep = ';', decimal = ',')

# %%
lambada.head()
# Out:
#                                                texto  label  \
# 0              What is the Homelite Inc. home page ?      5
# 1  Name the men 's cologne that is associated wit...      1
# 2  Name the men 's cologne that is associated wit...      1
# 3        What did the Seven Dwarfs do for a living ?      3
# 4  What U.S. state 's biggest lake is Lake Sam Ra...      5
#
#                                        parafraseador
# 0       What is the highest elevation in the world ?
# 1  Name the men 's jersey number on a baseball cap ?
# 2  Name the men 's bathing suit with a frog 's ta...
# 3  What did the first-rate baseball pitchers do w...
# 4               What U.S. President has been named ?

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
import sacrebleu



keyboard['BLEUscore'] = keyboard.progress_apply(lambda x: sacrebleu.sentence_bleu(x['texto'], [x['parafraseador']]), axis=1)
eda['BLEUscore'] = eda.progress_apply(lambda x: sacrebleu.sentence_bleu(x['texto'], [x['parafraseador']]), axis=1)
embed['BLEUscore'] = embed.progress_apply(lambda x: sacrebleu.sentence_bleu(x['texto'], [x['parafraseador']]), axis=1)
bert['BLEUscore'] = bert.progress_apply(lambda x: sacrebleu.sentence_bleu(x['texto'], [x['parafraseador']]), axis=1)
back_trans['BLEUscore'] = back_trans.progress_apply(lambda x: sacrebleu.sentence_bleu(str(x['texto']), [str(x['parafraseador'])]), axis=1)
deep_back['BLEUscore'] = deep_back.progress_apply(lambda x: sacrebleu.sentence_bleu(x['texto'], [x['parafraseador']]), axis=1)
parrot['BLEUscore'] = parrot.progress_apply(lambda x: sacrebleu.sentence_bleu(str(x['texto']), [str(x['parafraseador'])]), axis=1)
protaug['BLEUscore'] = protaug.progress_apply(lambda x: sacrebleu.sentence_bleu(str(x['texto']), [str(x['parafraseador'])]), axis=1)
lambada['BLEUscore'] = lambada.progress_apply(lambda x: sacrebleu.sentence_bleu(str(x['texto']), [str(x['parafraseador'])]), axis=1)
ppdb['BLEUscore'] = ppdb.progress_apply(lambda x: sacrebleu.sentence_bleu(str(x['texto']), [str(x['parafraseador'])]), axis=1)
ssmba['BLEUscore'] = ssmba.progress_apply(lambda x: sacrebleu.sentence_bleu(str(x['texto']), [str(x['parafraseador'])]), axis=1)
# Out:
# 100%|██████████| 5455/5455 [00:01<00:00, 2903.01it/s]
# 100%|██████████| 5455/5455 [00:01<00:00, 2916.97it/s]
# 100%|██████████| 5455/5455 [00:02<00:00, 2721.14it/s]
# 100%|██████████| 5455/5455 [00:01<00:00, 2753.73it/s]
# 100%|██████████| 5455/5455 [00:01<00:00, 3127.76it/s]
# 100%|██████████| 5455/5455 [00:01<00:00, 2818.36it/s]
# 100%|██████████| 4185/4185 [00:01<00:00, 3165.89it/s]
# 100%|██████████| 5455/5455 [00:02<00:00, 2592.16it/s]
# 100%|██████████| 5213/5213 [00:02<00:00, 2559.65it/s]
# 100%|██████████| 2730/2730 [00:00<00:00, 2997.95it/s]
# 100%|██████████| 5455/5455 [00:02<00:00, 2624.86it/s]

# %%
keyboard['BLEUscore_without_bp'] = keyboard['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
eda['BLEUscore_without_bp'] = eda['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
embed['BLEUscore_without_bp'] = embed['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
bert['BLEUscore_without_bp'] = bert['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
back_trans['BLEUscore_without_bp'] = back_trans['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
deep_back['BLEUscore_without_bp'] = deep_back['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
parrot['BLEUscore_without_bp'] = parrot['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
protaug['BLEUscore_without_bp'] = protaug['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
lambada['BLEUscore_without_bp'] = lambada['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
ppdb['BLEUscore_without_bp'] = ppdb['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
ssmba['BLEUscore_without_bp'] = ssmba['BLEUscore'].progress_apply(lambda x: x.score/x.bp)
# Out:
# 100%|██████████| 5455/5455 [00:00<00:00, 398077.95it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 401493.82it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 490196.64it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 492030.89it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 353614.64it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 505600.25it/s]
# 100%|██████████| 4185/4185 [00:00<00:00, 406210.36it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 535052.81it/s]
# 100%|██████████| 5213/5213 [00:00<00:00, 354742.47it/s]
# 100%|██████████| 2730/2730 [00:00<00:00, 521399.30it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 433940.15it/s]

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('sentence-transformers/paraphrase-albert-small-v2')
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.71k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/827 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/46.7M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/245 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/760k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/465 [00:00<?, ?B/s]

# %%
dataset = [keyboard, eda, embed, bert, back_trans, deep_back, parrot, protaug,lambada, ppdb,ssmba]

for base in dataset:
  original_embedding = model.encode(base['texto'].astype('str'))
  base['texto_embedding'] = [original_embedding[i] for i in range(original_embedding.shape[0])]
  parafrase_embedding = model.encode(base['parafraseador'].astype('str'))
  base['parafraseador_embedding'] = [parafrase_embedding[i] for i in range(parafrase_embedding.shape[0])]

# %%
for base in dataset:
  base['similiaridade_parafrase'] = base.progress_apply(lambda x:util.cos_sim(x['texto_embedding'], x['parafraseador_embedding']).tolist()[0][0], axis=1)
# Out:
# 100%|██████████| 5455/5455 [00:01<00:00, 5454.28it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 5631.47it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 5525.86it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 5548.79it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 5593.48it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 5641.13it/s]
# 100%|██████████| 4185/4185 [00:00<00:00, 5593.98it/s]
# 100%|██████████| 5455/5455 [00:01<00:00, 5381.94it/s]
# 100%|██████████| 5213/5213 [00:00<00:00, 5814.22it/s]
# 100%|██████████| 2730/2730 [00:00<00:00, 5597.18it/s]
# 100%|██████████| 5455/5455 [00:00<00:00, 5618.44it/s]

# %%
keyboard.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  5455.000000           5455.000000              5455.000000
# mean      2.355637             37.398604                 0.591248
# std       1.793321             13.690705                 0.155143
# min       0.000000              6.742556                 0.033929
# 25%       1.000000             27.301209                 0.490782
# 50%       3.000000             36.889397                 0.609565
# 75%       4.000000             44.717702                 0.708926
# max       5.000000            100.000000                 0.942382

# %%
eda.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  5455.000000           5455.000000              5455.000000
# mean      2.355637             26.745344                 0.727643
# std       1.793321             18.016458                 0.168002
# min       0.000000              0.000000                -0.012886
# 25%       1.000000             13.650604                 0.638868
# 50%       3.000000             21.364350                 0.764842
# 75%       4.000000             35.494811                 0.857869
# max       5.000000            100.000000                 0.992947

# %%
embed.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  5455.000000           5455.000000              5455.000000
# mean      2.355637             37.596338                 0.683894
# std       1.793321             17.743468                 0.134972
# min       0.000000              6.274655                 0.040586
# 25%       1.000000             24.274589                 0.606749
# 50%       3.000000             35.355339                 0.703823
# 75%       4.000000             50.000000                 0.785766
# max       5.000000            100.000000                 0.980908

# %%
bert.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  5455.000000           5455.000000              5455.000000
# mean      2.355637             23.379686                 0.693751
# std       1.793321             15.027218                 0.165240
# min       0.000000              2.688668                -0.063659
# 25%       1.000000             12.223076                 0.603613
# 50%       3.000000             18.995892                 0.725949
# 75%       4.000000             31.239399                 0.819290
# max       5.000000             86.334002                 0.971754

# %%
back_trans.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  5455.000000           5455.000000              5455.000000
# mean      2.355637             41.117389                 0.817943
# std       1.793321             26.654197                 0.135229
# min       0.000000              3.458592                 0.028527
# 25%       1.000000             19.640733                 0.772568
# 50%       3.000000             35.355339                 0.859624
# 75%       4.000000             56.591193                 0.909601
# max       5.000000            100.000000                 0.977613

# %%
deep_back.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  5455.000000           5455.000000              5455.000000
# mean      2.355637             40.382225                 0.802255
# std       1.793321             27.045546                 0.149079
# min       0.000000              0.000000                -0.044281
# 25%       1.000000             18.575058                 0.747057
# 50%       3.000000             34.389312                 0.851658
# 75%       4.000000             56.550957                 0.907854
# max       5.000000            100.000000                 0.999999

# %%
parrot.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  4185.000000           4185.000000              4185.000000
# mean      2.352688             28.803759                 0.855950
# std       1.809751             22.596091                 0.082167
# min       0.000000              0.000000                 0.082251
# 25%       1.000000             11.339582                 0.815288
# 50%       3.000000             21.364350                 0.873016
# 75%       4.000000             40.896015                 0.912267
# max       5.000000            100.000000                 1.000001

# %%
protaug.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  5455.000000           5455.000000              5455.000000
# mean      2.355637             68.718919                 0.896388
# std       1.793321             23.846742                 0.056864
# min       0.000000              5.063997                 0.411852
# 25%       1.000000             53.380606                 0.872193
# 50%       3.000000             72.597953                 0.909057
# 75%       4.000000             86.944174                 0.934348
# max       5.000000            100.000000                 0.992951

# %%
lambada.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  5213.000000           5213.000000              5213.000000
# mean      2.425283             25.522490                 0.475104
# std       1.739575             20.163750                 0.227997
# min       0.000000              0.000000                -0.108823
# 25%       1.000000             13.545994                 0.314680
# 50%       3.000000             19.070828                 0.464934
# 75%       4.000000             29.847459                 0.607537
# max       5.000000            100.000000                 1.000001

# %%
ppdb.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  2730.000000           2730.000000              2730.000000
# mean      2.360806             42.456790                 0.771642
# std       1.793642             16.459965                 0.106158
# min       0.000000              7.809850                 0.180976
# 25%       1.000000             30.213754                 0.714148
# 50%       3.000000             41.211838                 0.784797
# 75%       4.000000             51.401638                 0.845421
# max       5.000000            100.000000                 1.000001

# %%
ssmba.describe()
# Out:
#              label  BLEUscore_without_bp  similiaridade_parafrase
# count  5455.000000           5455.000000              5455.000000
# mean      2.355637             27.169410                 0.741162
# std       1.793321             16.772468                 0.156741
# min       0.000000              0.000000                -0.038352
# 25%       1.000000             14.211672                 0.665218
# 50%       3.000000             23.185078                 0.776188
# 75%       4.000000             36.555522                 0.856316
# max       5.000000             91.216791                 1.000001
